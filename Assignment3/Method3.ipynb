# %%
# For running inference on the TF-Hub module.
import tensorflow as tf
import tensorflow_hub as hub

# For saving 'feature vectors' into a txt file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path

# %%
#################################################
# Imports and function definitions
#################################################

# Numpy for loading image feature vectors from file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path

# json for storing data in json file
import json

# Annoy and Scipy for similarity calculation
from annoy import AnnoyIndex
from scipy import spatial
#################################################

# %%
# This function:
# Loads the JPEG image at the given path
# Decodes the JPEG image to a uint8 W X H X 3 tensor
# Resizes the image to 224 x 224 x 3 tensor
# Returns the pre processed image as 224 x 224 x 3 tensor
#################################################
def load_img(path):

  # Reads the image file and returns data type of string
  img = tf.io.read_file(path)

  # Decodes the image to W x H x 3 shape tensor with type of uint8
  img = tf.io.decode_jpeg(img, channels=3)

  # Resize the image to 224 x 244 x 3 shape tensor
  img = tf.image.resize_with_pad(img, 224, 224)

  # Converts the data type of uint8 to float32 by adding a new axis
  # This makes the img 1 x 224 x 224 x 3 tensor with the data type of float32
  # This is required for the mobilenet model we are using
  img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]

  return img

# %%
import certifi
import ssl

ssl._create_default_https_context = ssl._create_unverified_context
#################################################
# This function:
# Loads the mobilenet model in TF.HUB
# Makes an inference for all images stored in a local folder
# Saves each of the feature vectors in a file
#################################################
def get_image_feature_vectors():

  i = 0

  start_time = time.time()

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at %s" %time.ctime())
  print("---------------------------------")

  # Definition of module with using tfhub.dev handle
  module_handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4" 
  
  # Load the module
  module = hub.load(module_handle)

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors -  Started at %s" %time.ctime())
 

  # Loops through all images in a local folder
  for filename in glob.glob('FinalImage/*.jpg'): #assuming gif
    i = i + 1

    print("-----------------------------------------------------------------------------------------")
    print("Image count                     :%s" %i)
    print("Image in process is             :%s" %filename)

    # Loads and pre-process the image
    img = load_img(filename)

    # Calculate the image feature vector of the img
    features = module(img)   
  
    # Remove single-dimensional entries from the 'features' array
    feature_set = np.squeeze(features)  

    # Saves the image feature vectors into a file for later use

    outfile_name = os.path.basename(filename).split('.')[0] + ".npz"
    out_path = os.path.join('npz_file/', outfile_name)

    # Saves the 'feature_set' to a text file
    np.savetxt(out_path, feature_set, delimiter=',')

    print("Image feature vector saved to   :%s" %out_path)
  
  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors - Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))
  print("--- %s images processed ---------" %i)

# %%
#################################################
# This function reads from 'image_data.json' file
# Looks for a specific 'filename' value
# Returns the product id when product image names are matched 
# So it is used to find product id based on the product image name
#################################################
def match_id(filename):
  with open('image_data.json') as json_file:
    
    for file in json_file:
        seen = json.loads(file)

        for line in seen:
          
          if filename==line['imageName']:
            print(line)
            return line['productId']
            break
#################################################

# %%
#################################################
# This function; 
# Reads all image feature vectores stored in /feature-vectors/*.npz
# Adds them all in Annoy Index
# Builds ANNOY index
# Calculates the nearest neighbors and image similarity metrics
# Stores image similarity scores with productID in a json file
#################################################
def cluster():

  start_time = time.time()
  
  print("---------------------------------")
  print ("Step.1 - ANNOY index generation - Started at %s" %time.ctime())
  print("---------------------------------")

  # Defining data structures as empty dict
  file_index_to_file_name = {}
  file_index_to_file_vector = {}
  file_index_to_product_id = {}

  # Configuring annoy parameters
  dims = 1792
  n_nearest_neighbors = 20
  trees = 10000

  # Reads all file names which stores feature vectors 
  allfiles = glob.glob('npz_file/*.npz')

  t = AnnoyIndex(dims, metric='angular')

  for file_index, i in enumerate(allfiles):
    
    # Reads feature vectors and assigns them into the file_vector 
    file_vector = np.loadtxt(i)

    # Assigns file_name, feature_vectors and corresponding product_id
    file_name = os.path.basename(i).split('.')[0]
    file_index_to_file_name[file_index] = file_name
    file_index_to_file_vector[file_index] = file_vector
    file_index_to_product_id[file_index] = match_id(file_name)

    # Adds image feature vectors into annoy index   
    t.add_item(file_index, file_vector)

    print("---------------------------------")
    print("Annoy index     : %s" %file_index)
    print("Image file name : %s" %file_name)
    print("Product id      : %s" %file_index_to_product_id[file_index])
    print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))


  # Builds annoy index
  t.build(trees)

  print ("Step.1 - ANNOY index generation - Finished")
  print ("Step.2 - Similarity score calculation - Started ") 
  
  named_nearest_neighbors = []

  # Loops through all indexed items
  for i in file_index_to_file_name.keys():

    # Assigns master file_name, image feature vectors and product id values
    master_file_name = file_index_to_file_name[i]
    master_vector = file_index_to_file_vector[i]
    master_product_id = file_index_to_product_id[i]

    # Calculates the nearest neighbors of the master item
    nearest_neighbors = t.get_nns_by_item(i, n_nearest_neighbors)

    # Loops through the nearest neighbors of the master item
    for j in nearest_neighbors:

      print(j)

      # Assigns file_name, image feature vectors and product id values of the similar item
      neighbor_file_name = file_index_to_file_name[j]
      neighbor_file_vector = file_index_to_file_vector[j]
      neighbor_product_id = file_index_to_product_id[j]

      # Calculates the similarity score of the similar item
      similarity = 1 - spatial.distance.cosine(master_vector, neighbor_file_vector)
      rounded_similarity = int((similarity * 10000)) / 10000.0

      # Appends master product id with the similarity score 
      # and the product id of the similar items
      named_nearest_neighbors.append({
        'similarity': rounded_similarity,
        'master_pi': master_product_id,
        'ImageLocation': file_name,
        'similar_pi': nearest_neighbors})

    print("---------------------------------") 
    print("Similarity index       : %s" %i)
    print("Master Image file name : %s" %file_index_to_file_name[i]) 
    print("Nearest Neighbors.     : %s" %master_vector) 
    print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  
  print ("Step.2 - Similarity score calculation - Finished ") 

  # Writes the 'named_nearest_neighbors' to a json file
  with open('nearest_neighbors.json', 'w') as out:
    json.dump(named_nearest_neighbors, out)

  print ("Step.3 - Data stored in 'nearest_neighbors.json' file ") 
  print("--- Prosess completed in %.2f minutes ---------" % ((time.time() - start_time)/60))

# %%
get_image_feature_vectors()
# Out:
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at Thu Nov  5 00:09:24 2020
# ---------------------------------
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at Thu Nov  5 00:09:29 2020
# --- 0.08 minutes passed ---------
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors -  Started at Thu Nov  5 00:09:29 2020
# -----------------------------------------------------------------------------------------
# Image count                     :1
# Image in process is             :FinalImage\0_0.jpg
# Image feature vector saved to   :npz_file/0_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :2
# Image in process is             :FinalImage\11_0.jpg
# Image feature vector saved to   :npz_file/11_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :3
# Image in process is             :FinalImage\12_0.jpg
# Image feature vector saved to   :npz_file/12_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :4
# Image in process is             :FinalImage\13_0.jpg
# Image feature vector saved to   :npz_file/13_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :5
# Image in process is             :FinalImage\13_1.jpg
# Image feature vector saved to   :npz_file/13_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :6
# Image in process is             :FinalImage\13_2.jpg
# Image feature vector saved to   :npz_file/13_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :7
# Image in process is             :FinalImage\13_3.jpg
# Image feature vector saved to   :npz_file/13_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :8
# Image in process is             :FinalImage\15_0.jpg
# Image feature vector saved to   :npz_file/15_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :9
# Image in process is             :FinalImage\16_0.jpg
# Image feature vector saved to   :npz_file/16_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :10
# Image in process is             :FinalImage\17_0.jpg
# Image feature vector saved to   :npz_file/17_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :11
# Image in process is             :FinalImage\18_0.jpg
# Image feature vector saved to   :npz_file/18_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :12
# Image in process is             :FinalImage\1_0.jpg
# Image feature vector saved to   :npz_file/1_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :13
# Image in process is             :FinalImage\2_0.jpg
# Image feature vector saved to   :npz_file/2_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :14
# Image in process is             :FinalImage\3_0.jpg
# Image feature vector saved to   :npz_file/3_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :15
# Image in process is             :FinalImage\4_0.jpg
# Image feature vector saved to   :npz_file/4_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :16
# Image in process is             :FinalImage\5_0.jpg
# Image feature vector saved to   :npz_file/5_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :17
# Image in process is             :FinalImage\6_0.jpg
# Image feature vector saved to   :npz_file/6_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :18
# Image in process is             :FinalImage\7_0.jpg
# Image feature vector saved to   :npz_file/7_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :19
# Image in process is             :FinalImage\8_0.jpg
# Image feature vector saved to   :npz_file/8_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :20
# Image in process is             :FinalImage\9_0.jpg
# Image feature vector saved to   :npz_file/9_0.npz
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors - Completed at Thu Nov  5 00:09:31 2020
# --- 0.12 minutes passed ---------
# --- 20 images processed ---------

# %%
cluster()
# Out:
# ---------------------------------
# Step.1 - ANNOY index generation - Started at Thu Nov  5 00:09:32 2020
# ---------------------------------
# {'imageName': '0_0', 'productId': '1'}
# ---------------------------------
# Annoy index     : 0
# Image file name : 0_0
# Product id      : 1
# --- 0.00 minutes passed ---------
# {'imageName': '11_0', 'productId': '11'}
# ---------------------------------
# Annoy index     : 1
# Image file name : 11_0
# Product id      : 11
# --- 0.00 minutes passed ---------
# {'imageName': '12_0', 'productId': '12'}
# ---------------------------------
# Annoy index     : 2
# Image file name : 12_0
# Product id      : 12
# --- 0.00 minutes passed ---------
# {'imageName': '13_0', 'productId': '13'}
# ---------------------------------
# Annoy index     : 3
# Image file name : 13_0
# Product id      : 13
# --- 0.00 minutes passed ---------
# {'imageName': '13_1', 'productId': '14'}
# ---------------------------------
# Annoy index     : 4
# Image file name : 13_1
# Product id      : 14
# --- 0.00 minutes passed ---------
# {'imageName': '13_2', 'productId': '15'}
# ---------------------------------
# Annoy index     : 5
# Image file name : 13_2
# Product id      : 15
# --- 0.00 minutes passed ---------
# {'imageName': '13_3', 'productId': '16'}
# ---------------------------------
# Annoy index     : 6
# Image file name : 13_3
# Product id      : 16
# --- 0.01 minutes passed ---------
# {'imageName': '15_0', 'productId': '17'}
# ---------------------------------
# Annoy index     : 7
# Image file name : 15_0
# Product id      : 17
# --- 0.01 minutes passed ---------
# {'imageName': '16_0', 'productId': '18'}
# ---------------------------------
# Annoy index     : 8
# Image file name : 16_0
# Product id      : 18
# --- 0.01 minutes passed ---------
# {'imageName': '17_0', 'productId': '19'}
# ---------------------------------
# Annoy index     : 9
# Image file name : 17_0
# Product id      : 19
# --- 0.01 minutes passed ---------
# {'imageName': '18_0', 'productId': '20'}
# ---------------------------------
# Annoy index     : 10
# Image file name : 18_0
# Product id      : 20
# --- 0.01 minutes passed ---------
# {'imageName': '1_0', 'productId': '2'}
# ---------------------------------
# Annoy index     : 11
# Image file name : 1_0
# Product id      : 2
# --- 0.01 minutes passed ---------
# {'imageName': '2_0', 'productId': '3'}
# ---------------------------------
# Annoy index     : 12
# Image file name : 2_0
# Product id      : 3
# --- 0.01 minutes passed ---------
# {'imageName': '3_0', 'productId': '4'}
# ---------------------------------
# Annoy index     : 13
# Image file name : 3_0
# Product id      : 4
# --- 0.01 minutes passed ---------
# {'imageName': '4_0', 'productId': '5'}
# ---------------------------------
# Annoy index     : 14
# Image file name : 4_0
# Product id      : 5
# --- 0.01 minutes passed ---------
# {'imageName': '5_0', 'productId': '6'}
# ---------------------------------
# Annoy index     : 15
# Image file name : 5_0
# Product id      : 6
# --- 0.01 minutes passed ---------
# {'imageName': '6_0', 'productId': '7'}
# ---------------------------------
# Annoy index     : 16
# Image file name : 6_0
# Product id      : 7
# --- 0.01 minutes passed ---------
# {'imageName': '7_0', 'productId': '8'}
# ---------------------------------
# Annoy index     : 17
# Image file name : 7_0
# Product id      : 8
# --- 0.02 minutes passed ---------
# {'imageName': '8_0', 'productId': '9'}
# ---------------------------------
# Annoy index     : 18
# Image file name : 8_0
# Product id      : 9
# --- 0.02 minutes passed ---------
# {'imageName': '9_0', 'productId': '10'}
# ---------------------------------
# Annoy index     : 19
# Image file name : 9_0
# Product id      : 10
# --- 0.02 minutes passed ---------
# Step.1 - ANNOY index generation - Finished
# Step.2 - Similarity score calculation - Started
# 0
# 11
# 1
# 18
# 12
# 13
# 7
# 9
# 17
# 10
# 6
# 3
# 14
# 4
# 15
# 16
# 8
# 2
# 5
# 19
# ---------------------------------
# Similarity index       : 0
# Master Image file name : 0_0
# Nearest Neighbors.     : [0.53657025 0.33945438 0.         ... 0.06473181 0.08374257 0.20033568]
# --- 0.03 minutes passed ---------
# 1
# 0
# 14
# 18
# 12
# 10
# 7
# 11
# 13
# 8
# 9
# 2
# 17
# 3
# 4
# 19
# 15
# 6
# 16
# 5
# ---------------------------------
# Similarity index       : 1
# Master Image file name : 11_0
# Nearest Neighbors.     : [1.42285359 0.88646215 0.         ... 0.0209614  0.07719547 0.0162651 ]
# --- 0.03 minutes passed ---------
# 2
# 1
# 10
# 14
# 18
# 0
# 7
# 8
# 9
# 19
# 11
# 12
# 17
# 4
# 6
# 3
# 13
# 16
# 15
# 5
# ---------------------------------
# Similarity index       : 2
# Master Image file name : 12_0
# Nearest Neighbors.     : [0.41822216 0.50132418 0.         ... 0.06754233 0.         0.3197329 ]
# --- 0.03 minutes passed ---------
# 3
# 6
# 4
# 5
# 18
# 16
# 0
# 12
# 17
# 13
# 14
# 1
# 11
# 10
# 9
# 7
# 15
# 8
# 19
# 2
# ---------------------------------
# Similarity index       : 3
# Master Image file name : 13_0
# Nearest Neighbors.     : [0.01619583 0.84399742 0.         ... 0.68658125 0.         0.05238993]
# --- 0.03 minutes passed ---------
# 4
# 6
# 3
# 16
# 0
# 12
# 17
# 18
# 13
# 14
# 11
# 1
# 10
# 5
# 7
# 9
# 15
# 2
# 8
# 19
# ---------------------------------
# Similarity index       : 4
# Master Image file name : 13_1
# Nearest Neighbors.     : [0.03480159 0.7612114  0.         ... 0.05884321 0.18311743 0.13367206]
# --- 0.03 minutes passed ---------
# 5
# 6
# 3
# 16
# 13
# 4
# 17
# 12
# 0
# 18
# 11
# 15
# 7
# 1
# 9
# 14
# 10
# 8
# 19
# 2
# ---------------------------------
# Similarity index       : 5
# Master Image file name : 13_2
# Nearest Neighbors.     : [0.         0.12364975 0.         ... 0.15999107 2.04311657 0.5789181 ]
# --- 0.03 minutes passed ---------
# 6
# 4
# 3
# 16
# 5
# 17
# 12
# 0
# 18
# 13
# 11
# 1
# 14
# 7
# 9
# 10
# 15
# 8
# 2
# 19
# ---------------------------------
# Similarity index       : 6
# Master Image file name : 13_3
# Nearest Neighbors.     : [0.09557225 0.02332632 0.         ... 0.84077531 0.42486945 0.15047151]
# --- 0.03 minutes passed ---------
# 7
# 8
# 12
# 0
# 11
# 1
# 17
# 18
# 9
# 13
# 10
# 14
# 6
# 2
# 19
# 3
# 15
# 4
# 16
# 5
# ---------------------------------
# Similarity index       : 7
# Master Image file name : 15_0
# Nearest Neighbors.     : [0.52230692 1.52702796 0.         ... 0.32618332 0.         0.31149575]
# --- 0.03 minutes passed ---------
# 8
# 7
# 12
# 1
# 14
# 18
# 9
# 10
# 19
# 17
# 0
# 2
# 11
# 13
# 3
# 15
# 6
# 4
# 5
# 16
# ---------------------------------
# Similarity index       : 8
# Master Image file name : 16_0
# Nearest Neighbors.     : [0.10690953 1.25905168 0.         ... 0.00650346 0.         0.01416303]
# --- 0.03 minutes passed ---------
# 9
# 18
# 0
# 11
# 1
# 7
# 8
# 17
# 12
# 15
# 10
# 13
# 2
# 3
# 6
# 14
# 19
# 16
# 4
# 5
# ---------------------------------
# Similarity index       : 9
# Master Image file name : 17_0
# Nearest Neighbors.     : [0.13420236 2.65640473 0.         ... 0.04939038 0.         0.        ]
# --- 0.03 minutes passed ---------
# 10
# 18
# 1
# 12
# 0
# 17
# 14
# 2
# 11
# 7
# 8
# 4
# 9
# 3
# 6
# 19
# 13
# 15
# 16
# 5
# ---------------------------------
# Similarity index       : 10
# Master Image file name : 18_0
# Nearest Neighbors.     : [0.58211124 1.31132448 0.         ... 0.29571614 0.         0.07545992]
# --- 0.03 minutes passed ---------
# 11
# 0
# 18
# 7
# 1
# 9
# 17
# 12
# 13
# 10
# 4
# 6
# 3
# 15
# 14
# 8
# 16
# 2
# 19
# 5
# ---------------------------------
# Similarity index       : 11
# Master Image file name : 1_0
# Nearest Neighbors.     : [0.26903868 2.56870198 0.         ... 0.02436453 0.00897591 0.        ]
# --- 0.03 minutes passed ---------
# 12
# 17
# 0
# 1
# 7
# 18
# 10
# 6
# 8
# 14
# 13
# 3
# 4
# 11
# 16
# 9
# 5
# 15
# 2
# 19
# ---------------------------------
# Similarity index       : 12
# Master Image file name : 2_0
# Nearest Neighbors.     : [0.0384659  0.01087872 0.         ... 0.         0.         0.05359227]
# --- 0.03 minutes passed ---------
# 13
# 18
# 0
# 17
# 1
# 12
# 3
# 6
# 7
# 11
# 15
# 4
# 5
# 9
# 8
# 16
# 14
# 10
# 19
# 2
# ---------------------------------
# Similarity index       : 13
# Master Image file name : 3_0
# Nearest Neighbors.     : [0.40704346 2.14007902 0.         ... 0.03191324 0.01764671 0.02334045]
# --- 0.03 minutes passed ---------
# 14
# 1
# 12
# 0
# 8
# 10
# 18
# 3
# 7
# 4
# 2
# 11
# 6
# 17
# 9
# 13
# 19
# 15
# 16
# 5
# ---------------------------------
# Similarity index       : 14
# Master Image file name : 4_0
# Nearest Neighbors.     : [0.61609316 0.59542704 0.         ... 0.         0.         0.        ]
# --- 0.03 minutes passed ---------
# 15
# 0
# 13
# 18
# 11
# 1
# 9
# 12
# 7
# 17
# 6
# 3
# 16
# 4
# 14
# 10
# 5
# 8
# 19
# 2
# ---------------------------------
# Similarity index       : 15
# Master Image file name : 5_0
# Nearest Neighbors.     : [0.16023831 1.23399472 0.         ... 0.         1.04475975 0.05830564]
# --- 0.03 minutes passed ---------
# 16
# 6
# 4
# 3
# 0
# 5
# 12
# 17
# 18
# 11
# 13
# 1
# 9
# 7
# 15
# 10
# 14
# 8
# 2
# 19
# ---------------------------------
# Similarity index       : 16
# Master Image file name : 6_0
# Nearest Neighbors.     : [0.15923718 0.11660452 0.         ... 1.25510645 0.77276969 0.10797209]
# --- 0.03 minutes passed ---------
# 17
# 18
# 12
# 13
# 6
# 0
# 7
# 1
# 10
# 4
# 3
# 11
# 8
# 16
# 9
# 5
# 14
# 15
# 2
# 19
# ---------------------------------
# Similarity index       : 17
# Master Image file name : 7_0
# Nearest Neighbors.     : [0.00301939 0.78287786 0.         ... 1.65535545 0.         1.34960628]
# --- 0.03 minutes passed ---------
# 18
# 0
# 17
# 1
# 11
# 10
# 9
# 12
# 13
# 7
# 3
# 6
# 14
# 4
# 8
# 15
# 2
# 16
# 19
# 5
# ---------------------------------
# Similarity index       : 18
# Master Image file name : 8_0
# Nearest Neighbors.     : [0.4291856  2.38297892 0.         ... 0.59126824 0.01154805 0.10293055]
# --- 0.03 minutes passed ---------
# 19
# 8
# 1
# 7
# 18
# 2
# 9
# 10
# 12
# 0
# 17
# 14
# 11
# 13
# 3
# 15
# 6
# 5
# 4
# 16
# ---------------------------------
# Similarity index       : 19
# Master Image file name : 9_0
# Nearest Neighbors.     : [0.         2.1664288  0.         ... 0.32639557 0.         0.49400148]
# --- 0.04 minutes passed ---------
# Step.2 - Similarity score calculation - Finished
# Step.3 - Data stored in 'nearest_neighbors.json' file
# --- Prosess completed in 0.04 minutes ---------
